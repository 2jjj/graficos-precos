# %% [markdown]
# Preço macbook

# %%
import matplotlib.pyplot as plt

meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho']
valores = [105235, 107697, 110256, 109236, 108859, 109986, 100040]

plt.plot(meses, valores)

# %% [markdown]
# Gráficos em barras, comparação do s21, s20FE e o iphone 11

# %%
cell = ['S21 128GB', 'S20FE 128GB', 'Iphone 11 64GB']
valores = [3599, 1799, 3689]
plt.title("Preços")
plt.bar(cell, valores, color='red')
plt.show()
